# %%
import pandas as pd
import numpy as np

# %%
data=pd.DataFrame()
data['Populaion']=[23,34,45,67,78,89,90]

# %%
a_sample_with_replacement=data['Populaion'].sample(5,replace=True)

# %%
print(a_sample_with_replacement)
# Out:
# 6    90
# 4    78
# 6    90
# 5    89
# 2    45
# Name: Populaion, dtype: int64

# %%
a_sample_without_replacement=data['Populaion'].sample(5,replace=False)

# %%
print(a_sample_without_replacement)
# Out:
# 4    78
# 3    67
# 6    90
# 0    23
# 2    45
# Name: Populaion, dtype: int64

# %%
population_mean=data['Populaion'].mean()

# %%
print(population_mean)
# Out:
# 60.857142857142854

# %%
population_std=data['Populaion'].std(ddof=0)

# %%
print(population_meann)
# Out:
# 25.01101798024549

# %%
population_var=data['Populaion'].var(ddof=0)

# %%
print(population_var)
# Out:
# 625.5510204081633

# %%
sample_length=500
sample_variance_collection=[data['Populaion'].sample(10,replace=True) for i in range(sample_length)]

# %%
print(sample_variance_collection)
# Out:
# [0    23
# 4    78
# 1    34
# 4    78
# 1    34
# 2    45
# 3    67
# 0    23
# 6    90
# 3    67
# Name: Populaion, dtype: int64, 0    23
# 0    23
# 0    23
# 5    89
# 4    78
# 3    67
# 2    45
# 3    67
# 2    45
# 5    89
# Name: Populaion, dtype: int64, 2    45
# 6    90
# 2    45
# 2    45
# 4    78
# 2    45
# 5    89
# 0    23
# 5    89
# 3    67
# Name: Populaion, dtype: int64, 4    78
# 0    23
# 6    90
# 0    23
# 0    23
# 5    89
# 2    45
# 3    67
# 3    67
# 3    67
# Name: Populaion, dtype: int64, 3    67
# 1    34
# 0    23
# 5    89
# 3    67
# 5    89
# 3    67
# 4    78
# 0    23
# 1    34
# Name: Populaion, dtype: int64, 3    67
# 0    23
# 0    23
# 5    89
# 0    23
# 4    78
# 1    34
# 4    78
# 5    89
# 2    45
# Name: Populaion, dtype: int64, 2    45
# 2    45
# 3    67
# 4    78
# 4    78
# 1    34
# 3    67
# 3    67
# 1    34
# 6    90
# Name: Populaion, dtype: int64, 6    90
# 0    23
# 3    67
# 4    78
# 4    78
# 3    67
# 2    45
# 2    45
# ...
